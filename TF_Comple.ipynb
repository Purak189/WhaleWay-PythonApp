# %% [markdown]
# <a href="https://colab.research.google.com/github/Purak189/WhaleWay-PythonApp/blob/Gaboooo/TF_Comple.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Código para obtener un gráfico de Lima

# %%
# !pip install osmnx
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.2/107.2 kB 1.8 MB/s eta 0:00:00
# ...

# %%
import osmnx as ox

# %%
place_name = "Lima, Perú"
graph = ox.graph_from_place(place_name, which_result=1, network_type='drive')

# %% [markdown]
# #Muestra la figura de lima

# %%
fig, ax = ox.plot_graph(graph)

# %% [markdown]
# #Extraemos los nodos del mapa de lima
#
# > Añadir blockquote

# %%
nodes, edges = ox.graph_to_gdfs(graph)
print(nodes)
# Out:
#                      y          x  ref            highway  street_count  \
# osmid
# 258066779   -12.371360 -76.784678  45A  motorway_junction             3
# 258066780   -12.376318 -76.779559  NaN                NaN             3
# 258066781   -12.384553 -76.771046  NaN                NaN             3
# 258066783   -12.385783 -76.769768  NaN                NaN             3
# 258067237   -12.304254 -76.840727  NaN                NaN             3
# ...                ...        ...  ...                ...           ...
# 11932010360 -11.704637 -77.178225  NaN                NaN             3
# 11932010361 -11.705700 -77.181990  NaN                NaN             1
# 11932010362 -11.707114 -77.181653  NaN                NaN             3
# 11932010365 -11.708708 -77.181236  NaN                NaN             1
# 11932010366 -11.706703 -77.180227  NaN                NaN             3
#
#                                 geometry
# osmid
# 258066779    POINT (-76.78468 -12.37136)
# ...
